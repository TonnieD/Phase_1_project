# %% [markdown]
# # VISUALIZATIONS

# %% [markdown]
# After our data has been fully cleaned now e an use the __cleaned_aviation_data.csv__ file to plot meaningfull visuakization thet describe our data.
#
# We weil 1st need to import all the nesecsary libraries and load the data
#
# Atfer we will need to save the images in the visualizations folder inside the images folder.

# %%
#Importing all libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#We will also plot the vvisualization within this notebook
# %matplotlib inline

# %%
#load the cleaned_aviation_data.csv  data into a DataFrame
df = pd.read_csv('Data Sets/cleaned_aviation_data.csv ')
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      Sea87La080  1948-10-24
# 1      20001218X45447           Accident      Lax94La336  1962-07-19
# 2      20061025X01555           Accident      Nyc07La005  1974-08-30
# 3      20001218X45448           Accident      Lax96La321  1977-06-19
# 4      20041105X01764           Accident      Chi79Fa064  1979-08-02
# ...               ...                ...             ...         ...
# 82204  20221227106491           Accident      Era23La093  2022-12-26
# 82205  20221227106494           Accident      Era23La095  2022-12-26
# 82206  20221227106497           Accident      Wpr23La075  2022-12-26
# 82207  20221227106498           Accident      Wpr23La076  2022-12-26
# 82208  20221230106513           Accident      Era23La097  2022-12-29
#
#               Location        Country Aircraft.damage  \
# 0      Moose Creek, Id  United States       Destroyed
# 1       Bridgeport, Ca  United States       Destroyed
# 2        Saltville, Va  United States       Destroyed
# 3           Eureka, Ca  United States       Destroyed
# 4           Canton, Oh  United States       Destroyed
# ...                ...            ...             ...
# 82204    Annapolis, Md  United States         Unknown
# 82205      Hampton, Nh  United States         Unknown
# 82206       Payson, Az  United States     Substantial
# 82207       Morgan, Ut  United States         Unknown
# 82208       Athens, Ga  United States         Unknown
#
#                              Make      Model Amateur.Built  Number.of.Engines  \
# 0                         Stinson      108-3            No                1.0
# 1                           Piper   Pa24-180            No                1.0
# 2                          Cessna       172M            No                1.0
# 3                        Rockwell        112            No                1.0
# 4                          Cessna        501            No                1.0
# ...                           ...        ...           ...                ...
# 82204                       Piper  Pa-28-151            No                1.0
# 82205                    Bellanca       7Eca            No                1.0
# 82206  American Champion Aircraft      8Gcbc            No                1.0
# 82207                      Cessna       210N            No                1.0
# 82208                       Piper  Pa-24-260            No                1.0
#
#          Engine.Type  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0      Reciprocating                   2.0                     0.0
# 1      Reciprocating                   4.0                     0.0
# 2      Reciprocating                   3.0                     0.0
# 3      Reciprocating                   2.0                     0.0
# 4          Turbo Fan                   1.0                     2.0
# ...              ...                   ...                     ...
# 82204  Reciprocating                   0.0                     1.0
# 82205  Reciprocating                   0.0                     0.0
# 82206  Reciprocating                   0.0                     0.0
# 82207  Reciprocating                   0.0                     0.0
# 82208  Reciprocating                   0.0                     1.0
#
#        Total.Minor.Injuries  Total.Uninjured State.Abbreviation       US_State
# 0                       0.0              0.0                 ID          Idaho
# 1                       0.0              0.0                 CA     California
# 2                       0.0              1.0                 VA       Virginia
# 3                       0.0              0.0                 CA     California
# 4                       0.0              0.0                 OH           Ohio
# ...                     ...              ...                ...            ...
# 82204                   0.0              0.0                 MD       Maryland
# 82205                   0.0              0.0                 NH  New Hampshire
# 82206                   0.0              1.0                 AZ        Arizona
# 82207                   0.0              0.0                 UT           Utah
# 82208                   0.0              1.0                 GA        Georgia
#
# [82209 rows x 18 columns]

# %% [markdown]
# ## TRENDS

# %% [markdown]
# Under trends I will look at trends over the years how the number are if they are __increasing__, __decreasing__ or __fluctuating__.
# This will tell us if with time and perhaps if technological advancements have reduced, increased or had no affect on the aviation accidnts and incidents

# %% [markdown]
# Plots to be ploted here will be:
# - Trends of accidents and incedents over the years
# - Fatal, serious, Minor injuries and total uniured over the years
# - Trends of makes over the years
# - Trends by Aircraft damage over the years

# %% [markdown]
# First we will need to retrive the year from the 'Event.Date' column and create a year column containing only the year

# %%
#Convert the datatype of the 'Event.Date' column to datetime data type
df['Event.Date'] = pd.to_datetime(df['Event.Date'])

#Creating a years column by retrivinng the year from the 'Event.Date' column
df['Year'] = df['Event.Date'].dt.year
df[['Event.Date', 'Year']].head()
# Out:
#   Event.Date  Year
# 0 1948-10-24  1948
# 1 1962-07-19  1962
# 2 1974-08-30  1974
# 3 1977-06-19  1977
# 4 1979-08-02  1979

# %% [markdown]
# __After trying to plot with the number of years the years are too many to be clear on a plot so by having them in  decade would help the visualization look better__

# %%
# Create a Decade column
df['Decade'] = (df['Year'] // 10) * 10

#This converts the years into the nearest decade
df['Decade'].head()
# Out:
# 0    1940
# 1    1960
# 2    1970
# 3    1970
# 4    1970
# Name: Decade, dtype: int32

# %% [markdown]
# With our years column all done now we can start to plot

# %%
#Create figure and axes for each of our plots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('TRENDS OVER TIME', fontsize = 18, fontweight = 'bold')

#1st plot Trend of investigation type(accidents/incidents) over the years
investigation_counts = df.groupby(['Decade', 'Investigation.Type']).size().reset_index(name = 'Count')
sns.barplot(x = 'Decade', y = 'Count', hue = 'Investigation.Type', data = investigation_counts, ax = axes[0, 0])
axes[0, 0].set_title("Accident vs. Incident Over Time", fontweight = 'bold')

#2nd a line plot of the diffrent kind of inuries over the years 
yearly_trends = df.groupby('Year')[['Total.Fatal.Injuries', 'Total.Serious.Injuries', 
                                    'Total.Minor.Injuries', 'Total.Uninjured']].sum().reset_index()

# Plot in [0, 1] (Line Plot)
sns.lineplot(x = 'Year', y = 'Total.Fatal.Injuries', data = yearly_trends, label = 'Fatal Injuries', ax = axes[0, 1])
sns.lineplot(x = 'Year', y = 'Total.Serious.Injuries', data = yearly_trends, label = 'Serious Injuries', ax = axes[0, 1])
sns.lineplot(x = 'Year', y = 'Total.Minor.Injuries', data = yearly_trends, label = 'Minor Injuries', ax = axes[0, 1])
sns.lineplot(x = 'Year', y = 'Total.Uninjured', data = yearly_trends, label = 'Uninjured', ax = axes[0, 1])

axes[0, 1].set_title("Injury Trends Over the Years", fontweight = 'bold')
axes[0, 1].set_xlabel("Year")
axes[0, 1].set_ylabel("Number of Injuries")
axes[0, 1].tick_params(axis = 'x', rotation=45) 
axes[0, 1].legend(title = "Injury Type")

#3rd lineplot of make involved in accidents/incedents over time
#Since there are over 7400 diffrent makes we will use the top 5 makes
top_5_makes = df['Make'].value_counts().head(5).index  

#Filter dataset to only include top 5 makes
df_top_makes = df[df['Make'].isin(top_5_makes)]

#Group by Year and Make to count occurrences
make_trends = df_top_makes.groupby(['Year', 'Make']).size().reset_index(name = 'Count')

#Plot in [1, 0] (Line Plot for Top 5 Makes Over Time)
for make in top_5_makes:
    sns.lineplot(x = 'Year', y = 'Count', data=make_trends[make_trends['Make'] == make], label = make, ax = axes[1, 0])

axes[1, 0].set_title("Top 5 Aircraft Makes in Accidents/Incidents Over Time", fontweight = 'bold')
axes[1, 0].set_xlabel("Year")
axes[1, 0].set_ylabel("Number of Accidents/Incidents")
axes[1, 0].tick_params(axis = 'x', rotation = 45)
axes[1, 0].legend(title = "Aircraft Make")

#4th lineplot of aircraft damage over the years
damage_trends = df.groupby(['Year', 'Aircraft.damage']).size().reset_index(name='Count')

# Plot in [1, 1] (Line Plot for Aircraft Damage Over Time)
for damage_type in df['Aircraft.damage'].unique():
    sns.lineplot(x='Year', y='Count', data=damage_trends[damage_trends['Aircraft.damage'] == damage_type], 
                 label=damage_type, ax=axes[1, 1])

# Formatting
axes[1, 1].set_title("Aircraft Damage Over the Years", fontweight='bold')
axes[1, 1].set_xlabel("Year")
axes[1, 1].set_ylabel("Number of Accidents/Incidents")
axes[1, 1].tick_params(axis='x', rotation=45)
axes[1, 1].legend(title="Aircraft Damage Type")

#save the image to visualization folder inside the images folder
plt.savefig("Images/Visualizations/trends_analysis.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## DISTRIBUTION OF NUMERICAL COLUMNS

# %% [markdown]
# This will help us see how all the numerical values are distributed in our data
#
# For this plot we will use the following columns:
# - Total.Fatal.Injuries
# - Total.Serious.Injuries
# - Total.Minor.Injuries
# - Total.Uninjured
# - Number.of.Engines

# %%
#remove outliers 1st
def remove_outliers(data):
    Q1 = np.percentile(data.dropna(), 25)
    Q3 = np.percentile(data.dropna(), 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data >= lower_bound) & (data <= upper_bound)]
    
#create figure axis for plots
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
fig.suptitle('FREQUENCY DISTRIBUTIONS OF NUMERICAL COLUMNS', fontsize = 18, fontweight = 'bold')

#1st TOtatal uninjured
sns.histplot(remove_outliers(df['Total.Uninjured']), bins = 5, color = 'red', alpha = 0.5,ax = axes[0,0])
axes[0, 0].set_title("Total Uninjured", fontweight = 'bold')

#2nd Fatal injuries
sns.histplot(df['Total.Fatal.Injuries'], bins = 5, color = 'blue', alpha = 0.5,ax = axes[0,1])
axes[0, 1].set_title("Total Fatal Injuries", fontweight = 'bold')


#3rd Number of engines
sns.histplot(df['Number.of.Engines'], bins = 5, color = 'yellow', alpha = 0.5,ax = axes[1,0])
axes[1, 0].set_title("Number of Engines", fontweight = 'bold')

#4th Minor Injuries
sns.histplot(df['Total.Minor.Injuries'], bins = 5, color = 'green', alpha = 0.5,ax = axes[1,1])
axes[1, 1].set_title("Total Minor Injuries", fontweight = 'bold')

#1st Serious Injuries
sns.histplot(df['Total.Serious.Injuries'], bins = 5, color = 'cyan', alpha = 0.5,ax = axes[2,0])
axes[2, 0].set_title("Total Serious Injuries", fontweight = 'bold')

#Removing the extra axis
axes[2,1].axis('off')

#removing overlap and saving our plot to a distributions figure
plt.tight_layout()
plt.savefig("Images/Visualizations/Distributions.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# The above plots sugest that most of the data is concentrated around zero with some very big outliers hence making our histo grams look like this

# %% [markdown]
# ## CORRELATION MATRIX

# %% [markdown]
# This will show us how our data how and in what degree they are corelated

# %%
# Select only numerical columns
num_df = df.select_dtypes(include=['number'])

# Compute correlation matrix
corr_matrix = num_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numerical Features", fontsize=14, fontweight="bold")


#Save the image
plt.savefig("Images/Visualizations/Correlation_matrix.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## SCATTER PLOTS

# %%
# Create figure with subplots (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("Scatter Plots of Key Relationships", fontsize=16, fontweight='bold')

# 1st Total Fatal Injuries vs. Number of Engines
sns.scatterplot(x=df["Number.of.Engines"], y=df["Total.Fatal.Injuries"], alpha=0.5, ax=axes[0, 0])
axes[0, 0].set_title("Total Fatal Injuries vs. Number of Engines")
axes[0, 0].set_xlabel("Number of Engines")
axes[0, 0].set_ylabel("Total Fatal Injuries")

# 2nd Total Fatal Injuries vs. Total Serious Injuries
sns.scatterplot(x=df["Total.Serious.Injuries"], y=df["Total.Fatal.Injuries"], alpha=0.5, ax=axes[0, 1])
axes[0, 1].set_title("Total Fatal Injuries vs. Total Serious Injuries")
axes[0, 1].set_xlabel("Total Serious Injuries")
axes[0, 1].set_ylabel("Total Fatal Injuries")

# 3rd Total Injuries vs. Year
sns.scatterplot(x=df["Year"], y=df["Total.Fatal.Injuries"] + df["Total.Serious.Injuries"], alpha=0.5, ax=axes[1, 0])
axes[1, 0].set_title("Total Injuries Over Time")
axes[1, 0].set_xlabel("Year")
axes[1, 0].set_ylabel("Total Injuries (Fatal + Serious)")

# Remove empyty axis
axes[1, 1].axis("off")

# Adjust layout to prevent overlap and save image
plt.tight_layout()
plt.savefig("Images/Visualizations/Scatter_plots.png", dpi=300, bbox_inches='tight')
plt.show()
